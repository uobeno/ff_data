# %% [markdown]
# # todotodotodo
# todotodotodoto

# %%
import os
from pathlib import Path
from sqlalchemy import create_engine

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import mplcursors

# %%
# Define your database file path (SQLite example)
rel_db_path = Path.cwd().parent.parent / 'raw_data' / 'nfl' / 'src_code' / 'nfl.db'
db_file_path = rel_db_path.resolve()

# %%
engine = create_engine(f'sqlite:///{db_file_path}')

# %%
# %load_ext sql

# %%
# %sql sqlite:///{db_file_path}

# %%
# %%sql
# SELECT *
# FROM nfl_results
# LIMIT 10
# Out:
#  * sqlite:////Users/beoconno/Documents/ff/ff_data/raw_data/nfl/src_code/nfl.db
# Done.
# [(1, 'David Johnson*+', 'ARI', 'RB', 25, 16, 16, 0, 0, 0, 0, 0, 293, 1239, 4.23, 16, 120, 80, 879, 10.99, 4, 5.0, 3, 20, 1.0, None, 328.0, 407.8, 416.8, 367.8, 191.0, 1, 1.0, 'JohnDa08', '2016'),
#  (2, 'Ezekiel Elliott*+', 'DAL', 'RB', 21, 15, 15, 0, 0, 0, 0, 0, 322, 1631, 5.07, 15, 39, 32, 363, 11.34, 1, 5.0, 1, 16, None, None, 293.0, 325.4, 332.4, 309.4, 156.0, 2, 2.0, 'ElliEz00', '2016'),
#  (3, 'Aaron Rodgers*', 'GNB', 'QB', 33, 16, 16, 401, 610, 4428, 40, 7, 67, 369, 5.51, 4, 0, 0, 0, None, 0, 8.0, 4, 4, 1.0, 1.0, 380.0, 380.0, 397.0, 387.0, 119.0, 1, 3.0, 'RodgAa00', '2016'),
#  (4, 'LeSean McCoy*', 'BUF', 'RB', 28, 15, 15, 0, 0, 0, 0, 0, 234, 1267, 5.41, 13, 57, 50, 356, 7.12, 1, 3.0, 0, 14, 1.0, None, 248.0, 298.3, 304.3, 273.3, 111.0, 3, 4.0, 'McCoLe01', '2016'),
#  (5, "Le'Veon Bell*", 'PIT', 'RB', 24, 12, 12, 0, 1, 0, 0, 0, 261, 1268, 4.86, 7, 94, 75, 616, 8.21, 2, 4.0, 1, 9, 1.0, None, 242.0, 317.4, 324.4, 279.9, 105.0, 4, 5.0, 'BellLe00', '2016'),
#  (6, 'DeMarco Murray*', 'TEN', 'RB', 28, 16, 16, 1, 2, 10, 1, 0, 293, 1287, 4.39, 9, 67, 53, 377, 7.11, 3, 3.0, 1, 12, None, None, 241.0, 293.8, 300.8, 267.3, 104.0, 5, 6.0, 'MurrDe00', '2016'),
#  (7, 'Devonta Freeman*', 'ATL', 'RB', 24, 16, 16, 0, 0, 0, 0, 0, 227, 1079, 4.75, 11, 65, 54, 462, 8.56, 2, 1.0, 1, 13, None, None, 230.0, 284.1, 291.1, 257.1, 93.0, 6, 7.0, 'FreeDe00', '2016'),
#  (8, 'LeGarrette Blount', 'NWE', 'RB', 30, 16, 8, 0, 0, 0, 0, 0, 299, 1161, 3.88, 18, 8, 7, 38, 5.43, 0, 2.0, 1, 18, None, None, 226.0, 232.9, 236.9, 229.4, 89.0, 7, 8.0, 'BlouLe00', '2016'),
#  (9, 'Matt Ryan*+', 'ATL', 'QB', 31, 16, 16, 373, 534, 4944, 38, 7, 35, 117, 3.34, 0, 0, 0, 0, None, 0, 4.0, 2, 0, 1.0, 1.0, 347.0, 347.5, 362.5, 354.5, 87.0, 2, 9.0, 'RyanMa00', '2016'),
#  (10, 'Mike Evans*', 'TAM', 'WR', 23, 16, 16, 0, 0, 0, 0, 0, 0, 0, None, 0, 173, 96, 1321, 13.76, 12, 0.0, 0, 12, 2.0, None, 208.0, 304.1, 307.1, 256.1, 82.0, 1, 10.0, 'EvanMi00', '2016')]

# %% [markdown]
# - keep in mind that a TIMESHARE backfield is one where someone has a LOT of points but doesn't get starts.
#
# - high g but lower gs
#
# - note: look later into people getting points from TD scoring or from production
#
# - start: average games played for the top 30 scoring for each position by points PER GAME
#
# - then: look at how often high PPG players play different percentages of the season
#
# - finally: compare the PPG finish vs the actual finish to see when people dissapoint?
#
# - also look at percent of games played by age of the player in the season?

# %%
percent_played = """
SELECT
    year,
    fantasy_pos,
    player,
    fantasy_points,
    g,
    ROUND(fantasy_points / g) AS fppg,
    ROUND(g / (IIF(year >= 2021, 17, 16)*1.00),2) AS pgp
FROM nfl_results
WHERE 1=1
    AND G > 1
    AND GS > 1
    AND ROUND(fantasy_points / g) > 5
ORDER BY fantasy_points / g DESC
"""

# %%
# %%sql
# $percent_played
# limit 10
# Out:
#  * sqlite:////Users/beoconno/Documents/ff/ff_data/raw_data/nfl/src_code/nfl.db
# Done.
# [('2019', 'QB', 'Lamar Jackson*+', 416.0, 15, 28.0, 0.94),
#  ('2020', 'QB', 'Dak Prescott', 135.0, 5, 27.0, 0.31),
#  ('2018', 'QB', 'Patrick Mahomes*+', 417.0, 16, 26.0, 1.0),
#  ('2022', 'QB', 'Jalen Hurts*', 378.0, 15, 25.0, 0.88),
#  ('2020', 'QB', 'Patrick Mahomes*', 374.0, 15, 25.0, 0.94),
#  ('2022', 'QB', 'Josh Allen*', 396.0, 16, 25.0, 0.94),
#  ('2020', 'QB', 'Josh Allen*', 395.0, 16, 25.0, 1.0),
#  ('2022', 'QB', 'Patrick Mahomes*+', 416.0, 17, 24.0, 1.0),
#  ('2020', 'RB', 'Christian McCaffrey', 73.0, 3, 24.0, 0.19),
#  ('2017', 'QB', 'Deshaun Watson', 169.0, 7, 24.0, 0.44)]

# %%
avg_played = """
SELECT
    fantasy_pos,
    MIN(ROUND(fantasy_points / g)) AS min_fppg,
    AVG(ROUND(fantasy_points / g)) AS av_fppg,
    MAX(ROUND(fantasy_points / g)) AS max_fppg,
    MIN(ROUND(g / (IIF(year >= 2021, 17, 16)*1.00),2)) AS min_pgp,
    AVG(ROUND(g / (IIF(year >= 2021, 17, 16)*1.00),2)) AS av_pgp,
    MAX(ROUND(g / (IIF(year >= 2021, 17, 16)*1.00),2)) AS max_pgp
FROM nfl_results
WHERE 1=1
    AND G > 1
    AND GS > 1
    AND ROUND(fantasy_points / g) > 5
GROUP BY 1
"""

# %%
# %%sql
# $avg_played
# LIMIT 10
# Out:
#  * sqlite:////Users/beoconno/Documents/ff/ff_data/raw_data/nfl/src_code/nfl.db
# Done.
# [('QB', 6.0, 14.753387533875339, 28.0, 0.12, 0.7080216802168018, 1.0),
#  ('RB', 6.0, 10.506527415143603, 24.0, 0.12, 0.8238903394255855, 1.0),
#  ('TE', 6.0, 7.573770491803279, 14.0, 0.13, 0.8500819672131139, 1.0),
#  ('WR', 6.0, 8.578125, 17.0, 0.18, 0.8606249999999981, 1.06)]

# %%
percent_played_data = %sql $percent_played

# Sample DataFrame (replace with your actual DataFrame)
data = percent_played_data
df = pd.DataFrame(data)

# The shading dataframe
shading_data = %sql $avg_played
shading_df = pd.DataFrame(shading_data)


# Function to add shading based on av_fppg and max_fppg from shading_df
def add_shading_lines(data, color, **kwargs):
    ax = plt.gca()
    fantasy_pos = data['fantasy_pos'].iloc[0]
    
    shading_values = shading_df[shading_df['fantasy_pos'] == fantasy_pos]
    
    if not shading_values.empty:
        av_fppg = shading_values['av_fppg'].values[0]
        max_fppg = shading_values['max_fppg'].values[0]
        
        av_pgp = shading_values['av_pgp'].values[0]
        min_pgp = shading_values['min_pgp'].values[0]
        
        # Horizontal shading
        ax.axhspan(av_fppg, max_fppg, color='green', alpha=0.01)
        ax.axhline(y=av_fppg, color='green', linestyle='--')

        # Vertical shading
        ax.axvspan(min_pgp, av_pgp, color='red', alpha=0.01)
        ax.axvline(x=av_pgp, color='red', linestyle='--')

# Create a FacetGrid
g = sns.FacetGrid(df, row="fantasy_pos", hue="Year", aspect=2, height=4)

# Map the scatterplot onto the grid
g.map_dataframe(sns.scatterplot, "pgp", "fppg").add_legend(title='Year')

# Add shading for each subplot
g.map_dataframe(add_shading_lines)

# Customize the plot
g.set_axis_labels("Games Played", "Fantasy Points Per Game")
g.set_titles(row_template="{row_name}", col_template="{col_name}")
g.fig.subplots_adjust(top=0.9)
g.fig.suptitle('Scatter Plots of FPPG by Games Played for Each Fantasy Position')

plt.show()
# Out:
#  * sqlite:////Users/beoconno/Documents/ff/ff_data/raw_data/nfl/src_code/nfl.db
# Done.
#  * sqlite:////Users/beoconno/Documents/ff/ff_data/raw_data/nfl/src_code/nfl.db
# Done.

# %%
# %%sql
# SELECT
#     year,
#     fantasy_pos,
#     player,
#     g,
#     gs,
#     fantasy_points,
#     ROUND(fantasy_points / g) AS fppg,
#     ROUND(fantasy_points / gs) AS fppgs,
#     fantasy_rank_pos
#     # ADD IN A RANK TO COMPARE FPPG_RANK_POS VS FANTASY_RANK_POS
#     # TO SEE IF HIGH VALUE PLAYERS GET INJURED OR IF PLAYERS "POP" FOR A SHORT DURATION OF TIME
# FROM nfl_results
# WHERE 1=1
#     AND fantasy_pos = 'RB'
#     AND G > 1
# ORDER BY fantasy_points / g DESC
# LIMIT 30
# ;
# Out:
#  * sqlite:////Users/beoconno/Documents/ff/ff_data/raw_data/nfl/src_code/nfl.db
# Done.
# [('2020', 'RB', 'Christian McCaffrey', 3, 3, 73.0, 24.0, 24.0, 51),
#  ('2018', 'RB', 'Todd Gurley*+', 14, 14, 313.0, 22.0, 22.0, 1),
#  ('2019', 'RB', 'Christian McCaffrey*+', 16, 16, 355.0, 22.0, 22.0, 1),
#  ('2021', 'RB', 'Derrick Henry', 8, 8, 175.0, 22.0, 22.0, 14),
#  ('2017', 'RB', 'Todd Gurley*+', 15, 15, 319.0, 21.0, 21.0, 1),
#  ('2020', 'RB', 'Dalvin Cook*', 14, 14, 294.0, 21.0, 21.0, 3),
#  ('2016', 'RB', 'David Johnson*+', 16, 16, 328.0, 21.0, 21.0, 1),
#  ('2023', 'RB', 'Christian McCaffrey*+', 16, 16, 324.0, 20.0, 20.0, 1),
#  ('2016', 'RB', "Le'Veon Bell*", 12, 12, 242.0, 20.0, 20.0, 4),
#  ('2020', 'RB', 'Alvin Kamara*', 15, 10, 295.0, 20.0, 30.0, 2),
#  ('2020', 'RB', 'Derrick Henry*+', 16, 16, 314.0, 20.0, 20.0, 1),
#  ('2021', 'RB', 'Jonathan Taylor*+', 17, 17, 333.0, 20.0, 20.0, 1),
#  ('2016', 'RB', 'Ezekiel Elliott*+', 15, 15, 293.0, 20.0, 20.0, 2),
#  ('2018', 'RB', 'Melvin Gordon*', 12, 12, 226.0, 19.0, 19.0, 6),
#  ('2023', 'RB', 'Kyren Williams*', 12, 11, 223.0, 19.0, 20.0, 4),
#  ('2018', 'RB', 'Kareem Hunt', 11, 11, 204.0, 19.0, 19.0, 8),
#  ('2019', 'RB', 'Derrick Henry*', 15, 15, 277.0, 18.0, 18.0, 2),
#  ('2018', 'RB', 'Saquon Barkley*', 16, 16, 295.0, 18.0, 18.0, 2),
#  ('2018', 'RB', 'Alvin Kamara*', 15, 13, 273.0, 18.0, 21.0, 4),
#  ('2017', 'RB', 'Ezekiel Elliott', 10, 10, 177.0, 18.0, 18.0, 9),
#  ('2018', 'RB', 'Christian McCaffrey', 16, 16, 279.0, 17.0, 17.0, 3),
#  ('2018', 'RB', 'James Conner*', 13, 12, 225.0, 17.0, 19.0, 7),
#  ('2017', 'RB', "Le'Veon Bell*+", 15, 15, 257.0, 17.0, 17.0, 2),
#  ('2021', 'RB', 'Austin Ekeler', 16, 16, 274.0, 17.0, 17.0, 2),
#  ('2019', 'RB', 'Dalvin Cook*', 14, 14, 239.0, 17.0, 17.0, 5),
#  ('2022', 'RB', 'Derrick Henry*', 16, 16, 270.0, 17.0, 17.0, 3),
#  ('2018', 'RB', 'Ezekiel Elliott*', 15, 15, 252.0, 17.0, 17.0, 5),
#  ('2019', 'RB', 'Aaron Jones', 16, 16, 266.0, 17.0, 17.0, 3),
#  ('2016', 'RB', 'LeSean McCoy*', 15, 15, 248.0, 17.0, 17.0, 3),
#  ('2023', 'RB', 'Raheem Mostert*', 15, 15, 243.0, 16.0, 16.0, 2)]

# %%
tag_played = """
CREATE TABLE pgp_tag AS 
WITH ppg AS (
    SELECT
        year,
        fantasy_pos,
        player,
        fantasy_points,
        g,
        ROUND(fantasy_points / g) AS fppg,
        ROUND(g / (IIF(year >= 2021, 17, 16)*1.00),2) AS pgp
    FROM nfl_results
    WHERE 1=1
        AND G > 1
        AND GS > 1
        AND ROUND(fantasy_points / g) > 5
),
av AS (
    SELECT
        fantasy_pos AS av_fpos,
        AVG(ROUND(fantasy_points / g)) AS av_fppg,
        AVG(ROUND(g / (IIF(year >= 2021, 17, 16)*1.00),2)) AS av_pgp
    FROM nfl_results
    WHERE 1=1
        AND G > 1
        AND GS > 1
        AND ROUND(fantasy_points / g) > 5
    GROUP BY 1
)
SELECT
    ppg.*,
    av.*,
    IIF(fppg>av_fppg, 'Top half scorer','Bottom half scorer') AS score_flag,
    IIF(pgp>av_pgp, 'Top half availability','Bottom half availability') AS availability_flag
FROM ppg
INNER JOIN av
ON ppg.fantasy_pos = av.av_fpos
;
"""

# %%
# %%sql
# $tag_played
# Out:
#  * sqlite:////Users/beoconno/Documents/ff/ff_data/raw_data/nfl/src_code/nfl.db
# Done.
# []

# %%
# %%sql
# SELECT
#     fantasy_pos,
#     score_flag,
#     availability_flag,
#     COUNT(1) AS player_count
# FROM pgp_tag
# GROUP BY 1, 2, 3
# ORDER BY 1, 2, 3
# ;
# Out:
#  * sqlite:////Users/beoconno/Documents/ff/ff_data/raw_data/nfl/src_code/nfl.db
# Done.
# [('QB', 'Bottom half scorer', 'Bottom half availability', 119),
#  ('QB', 'Bottom half scorer', 'Top half availability', 58),
#  ('QB', 'Top half scorer', 'Bottom half availability', 33),
#  ('QB', 'Top half scorer', 'Top half availability', 159),
#  ('RB', 'Bottom half scorer', 'Bottom half availability', 93),
#  ('RB', 'Bottom half scorer', 'Top half availability', 123),
#  ('RB', 'Top half scorer', 'Bottom half availability', 60),
#  ('RB', 'Top half scorer', 'Top half availability', 107),
#  ('TE', 'Bottom half scorer', 'Bottom half availability', 21),
#  ('TE', 'Bottom half scorer', 'Top half availability', 47),
#  ('TE', 'Top half scorer', 'Bottom half availability', 14),
#  ('TE', 'Top half scorer', 'Top half availability', 40),
#  ('WR', 'Bottom half scorer', 'Bottom half availability', 100),
#  ('WR', 'Bottom half scorer', 'Top half availability', 186),
#  ('WR', 'Top half scorer', 'Bottom half availability', 56),
#  ('WR', 'Top half scorer', 'Top half availability', 170)]

# %% [markdown]
# This is BAD for top scoring RBs. They are FRAGILE
#
# If you get an above average scorer. Here are the odds that they aren't available
# - 35% of RBs end up in bottom half availability
# - only 17% of top scoring QBs aren't availabile
# - only 25% of WRs/TEs aren't available
#
# We should look at how easily these players are to replace.
# For example, if 35% of the time a 20 point scoring RB is available for 8 games that is FINE if the replacement RB is scoring 18 points. You only take a 2 point epr week hit when they're out.
#
# However, if the drop off to a replacement RB is 8 points ... then you need to dock the expected points for drafting that RB.
#
# Drafting a 20 ppg RB is actually getting 20ppg for half the games and 12ppg for the other half. So you have a 16ppg running back.

# %% [markdown]
# ### which rbs busted?

# %%
# %%sql
# SELECT
#     year,
#     player,
#     g,
#     fppg,
#     pgp,
#     score_flag,
#     availability_flag
# FROM pgp_tag
# WHERE 1=1
#     AND fantasy_pos = 'RB'
#     AND score_flag LIKE 'Top%'
#     AND availability_flag NOT LIKE 'Top%'
# ORDER BY fppg DESC
# ;
# Out:
#  * sqlite:////Users/beoconno/Documents/ff/ff_data/raw_data/nfl/src_code/nfl.db
# Done.
# [('2020', 'Christian McCaffrey', 3, 24.0, 0.19, 'Top half scorer', 'Bottom half availability'),
#  ('2021', 'Derrick Henry', 8, 22.0, 0.47, 'Top half scorer', 'Bottom half availability'),
#  ('2016', "Le'Veon Bell*", 12, 20.0, 0.75, 'Top half scorer', 'Bottom half availability'),
#  ('2018', 'Melvin Gordon*', 12, 19.0, 0.75, 'Top half scorer', 'Bottom half availability'),
#  ('2018', 'Kareem Hunt', 11, 19.0, 0.69, 'Top half scorer', 'Bottom half availability'),
#  ('2023', 'Kyren Williams*', 12, 19.0, 0.71, 'Top half scorer', 'Bottom half availability'),
#  ('2017', 'Ezekiel Elliott', 10, 18.0, 0.63, 'Top half scorer', 'Bottom half availability'),
#  ('2018', 'James Conner*', 13, 17.0, 0.81, 'Top half scorer', 'Bottom half availability'),
#  ('2016', 'Melvin Gordon*', 13, 16.0, 0.81, 'Top half scorer', 'Bottom half availability'),
#  ('2020', 'Nick Chubb*', 12, 16.0, 0.75, 'Top half scorer', 'Bottom half availability'),
#  ('2017', 'Leonard Fournette', 13, 15.0, 0.81, 'Top half scorer', 'Bottom half availability'),
#  ('2019', 'Saquon Barkley', 13, 15.0, 0.81, 'Top half scorer', 'Bottom half availability'),
#  ('2023', "De'Von Achane", 11, 15.0, 0.65, 'Top half scorer', 'Bottom half availability'),
#  ('2017', 'Dalvin Cook', 4, 14.0, 0.25, 'Top half scorer', 'Bottom half availability'),
#  ('2021', 'Nick Chubb*', 14, 14.0, 0.82, 'Top half scorer', 'Bottom half availability'),
#  ('2021', 'Alvin Kamara*', 13, 14.0, 0.76, 'Top half scorer', 'Bottom half availability'),
#  ('2022', 'Breece Hall', 7, 14.0, 0.41, 'Top half scorer', 'Bottom half availability'),
#  ('2023', 'David Montgomery', 14, 14.0, 0.82, 'Top half scorer', 'Bottom half availability'),
#  ('2023', 'Jonathan Taylor', 10, 14.0, 0.59, 'Top half scorer', 'Bottom half availability'),
#  ('2016', 'Carlos Hyde', 13, 13.0, 0.81, 'Top half scorer', 'Bottom half availability'),
#  ('2018', 'Marlon Mack', 12, 13.0, 0.75, 'Top half scorer', 'Bottom half availability'),
#  ('2019', 'Josh Jacobs', 13, 13.0, 0.81, 'Top half scorer', 'Bottom half availability'),
#  ('2020', 'Chris Carson', 12, 13.0, 0.75, 'Top half scorer', 'Bottom half availability'),
#  ('2020', 'Joe Mixon', 6, 13.0, 0.38, 'Top half scorer', 'Bottom half availability'),
#  ('2021', 'Leonard Fournette', 14, 13.0, 0.82, 'Top half scorer', 'Bottom half availability'),
#  ('2021', 'Dalvin Cook*', 13, 13.0, 0.76, 'Top half scorer', 'Bottom half availability'),
#  ('2021', 'Elijah Mitchell', 11, 13.0, 0.65, 'Top half scorer', 'Bottom half availability'),
#  ('2021', 'Christian McCaffrey', 7, 13.0, 0.41, 'Top half scorer', 'Bottom half availability'),
#  ('2022', 'Joe Mixon', 14, 13.0, 0.82, 'Top half scorer', 'Bottom half availability'),
#  ('2023', 'Saquon Barkley', 14, 13.0, 0.82, 'Top half scorer', 'Bottom half availability'),
#  ('2023', 'James Conner', 13, 13.0, 0.76, 'Top half scorer', 'Bottom half availability'),
#  ('2016', 'C.J. Anderson', 7, 12.0, 0.44, 'Top half scorer', 'Bottom half availability'),
#  ('2018', 'Aaron Jones', 12, 12.0, 0.75, 'Top half scorer', 'Bottom half availability'),
#  ('2018', 'Leonard Fournette', 8, 12.0, 0.5, 'Top half scorer', 'Bottom half availability'),
#  ('2019', 'Melvin Gordon', 12, 12.0, 0.75, 'Top half scorer', 'Bottom half availability'),
#  ('2020', 'David Johnson', 12, 12.0, 0.75, 'Top half scorer', 'Bottom half availability'),
#  ('2020', 'Miles Sanders', 12, 12.0, 0.75, 'Top half scorer', 'Bottom half availability'),
#  ('2020', 'Myles Gaskin', 10, 12.0, 0.63, 'Top half scorer', 'Bottom half availability'),
#  ('2021', 'David Montgomery', 13, 12.0, 0.76, 'Top half scorer', 'Bottom half availability'),
#  ('2021', 'Rashaad Penny', 10, 12.0, 0.59, 'Top half scorer', 'Bottom half availability'),
#  ('2022', 'James Conner', 13, 12.0, 0.76, 'Top half scorer', 'Bottom half availability'),
#  ('2023', 'Isiah Pacheco', 14, 12.0, 0.82, 'Top half scorer', 'Bottom half availability'),
#  ('2023', 'Alvin Kamara', 13, 12.0, 0.76, 'Top half scorer', 'Bottom half availability'),
#  ('2016', 'Jonathan Stewart', 13, 11.0, 0.81, 'Top half scorer', 'Bottom half availability'),
#  ('2016', 'Theo Riddick', 10, 11.0, 0.63, 'Top half scorer', 'Bottom half availability'),
#  ('2016', 'Ameer Abdullah', 2, 11.0, 0.13, 'Top half scorer', 'Bottom half availability'),
#  ('2018', 'Kerryon Johnson', 10, 11.0, 0.63, 'Top half scorer', 'Bottom half availability'),
#  ('2018', 'Marshawn Lynch', 6, 11.0, 0.38, 'Top half scorer', 'Bottom half availability'),
#  ('2019', 'James Conner', 10, 11.0, 0.63, 'Top half scorer', 'Bottom half availability'),
#  ('2020', "D'Andre Swift", 13, 11.0, 0.81, 'Top half scorer', 'Bottom half availability'),
#  ('2020', 'Clyde Edwards-Helaire', 13, 11.0, 0.81, 'Top half scorer', 'Bottom half availability'),
#  ('2020', 'Jeff Wilson', 12, 11.0, 0.75, 'Top half scorer', 'Bottom half availability'),
#  ('2020', 'Austin Ekeler', 10, 11.0, 0.63, 'Top half scorer', 'Bottom half availability'),
#  ('2020', 'Raheem Mostert', 8, 11.0, 0.5, 'Top half scorer', 'Bottom half availability'),
#  ('2021', "D'Andre Swift", 13, 11.0, 0.76, 'Top half scorer', 'Bottom half availability'),
#  ('2021', 'Darrell Henderson', 12, 11.0, 0.71, 'Top half scorer', 'Bottom half availability'),
#  ('2021', 'Duke Johnson', 5, 11.0, 0.29, 'Top half scorer', 'Bottom half availability'),
#  ('2021', 'Chris Carson', 4, 11.0, 0.24, 'Top half scorer', 'Bottom half availability'),
#  ('2022', 'Jonathan Taylor', 11, 11.0, 0.65, 'Top half scorer', 'Bottom half availability'),
#  ('2023', 'Josh Jacobs', 13, 11.0, 0.76, 'Top half scorer', 'Bottom half availability')]

# %% [markdown]
# ### which wrs busted?

# %%
# %%sql
# SELECT
#     year,
#     player,
#     g,
#     fppg,
#     pgp,
#     score_flag,
#     availability_flag
# FROM pgp_tag
# WHERE 1=1
#     AND fantasy_pos = 'WR'
#     AND score_flag LIKE 'Top%'
#     AND availability_flag NOT LIKE 'Top%'
# ORDER BY fppg DESC
# ;
# Out:
#  * sqlite:////Users/beoconno/Documents/ff/ff_data/raw_data/nfl/src_code/nfl.db
# Done.
# [('2022', 'Cooper Kupp', 9, 14.0, 0.53, 'Top half scorer', 'Bottom half availability'),
#  ('2018', 'Odell Beckham Jr.', 12, 13.0, 0.75, 'Top half scorer', 'Bottom half availability'),
#  ('2019', 'Mike Evans*', 13, 13.0, 0.81, 'Top half scorer', 'Bottom half availability'),
#  ('2022', "Ja'Marr Chase*", 12, 13.0, 0.71, 'Top half scorer', 'Bottom half availability'),
#  ('2023', 'Keenan Allen*', 13, 13.0, 0.76, 'Top half scorer', 'Bottom half availability'),
#  ('2023', 'Justin Jefferson', 10, 13.0, 0.59, 'Top half scorer', 'Bottom half availability'),
#  ('2016', 'A.J. Green*', 10, 12.0, 0.63, 'Top half scorer', 'Bottom half availability'),
#  ('2017', 'Odell Beckham Jr.', 4, 12.0, 0.25, 'Top half scorer', 'Bottom half availability'),
#  ('2018', 'Cooper Kupp', 8, 12.0, 0.5, 'Top half scorer', 'Bottom half availability'),
#  ('2020', 'Will Fuller', 11, 12.0, 0.69, 'Top half scorer', 'Bottom half availability'),
#  ('2022', 'Michael Thomas', 3, 12.0, 0.18, 'Top half scorer', 'Bottom half availability'),
#  ('2018', 'Julian Edelman', 12, 11.0, 0.75, 'Top half scorer', 'Bottom half availability'),
#  ('2018', 'Emmanuel Sanders', 12, 11.0, 0.75, 'Top half scorer', 'Bottom half availability'),
#  ('2018', 'A.J. Green', 9, 11.0, 0.56, 'Top half scorer', 'Bottom half availability'),
#  ('2018', 'Will Fuller', 7, 11.0, 0.44, 'Top half scorer', 'Bottom half availability'),
#  ('2019', 'Tyreek Hill*', 12, 11.0, 0.75, 'Top half scorer', 'Bottom half availability'),
#  ('2019', 'Davante Adams*', 12, 11.0, 0.75, 'Top half scorer', 'Bottom half availability'),
#  ('2020', 'Chris Godwin', 12, 11.0, 0.75, 'Top half scorer', 'Bottom half availability'),
#  ('2020', 'Julio Jones', 9, 11.0, 0.56, 'Top half scorer', 'Bottom half availability'),
#  ('2021', 'DeAndre Hopkins', 10, 11.0, 0.59, 'Top half scorer', 'Bottom half availability'),
#  ('2021', 'Antonio Brown', 7, 11.0, 0.41, 'Top half scorer', 'Bottom half availability'),
#  ('2023', 'Tank Dell', 11, 11.0, 0.65, 'Top half scorer', 'Bottom half availability'),
#  ('2016', 'Dez Bryant*', 13, 10.0, 0.81, 'Top half scorer', 'Bottom half availability'),
#  ('2016', 'Eric Decker', 3, 10.0, 0.19, 'Top half scorer', 'Bottom half availability'),
#  ('2018', 'Albert Wilson', 7, 10.0, 0.44, 'Top half scorer', 'Bottom half availability'),
#  ('2019', 'Calvin Ridley', 13, 10.0, 0.81, 'Top half scorer', 'Bottom half availability'),
#  ('2019', 'Marvin Jones', 13, 10.0, 0.81, 'Top half scorer', 'Bottom half availability'),
#  ('2020', 'Brandon Aiyuk', 12, 10.0, 0.75, 'Top half scorer', 'Bottom half availability'),
#  ('2021', 'Tee Higgins', 14, 10.0, 0.82, 'Top half scorer', 'Bottom half availability'),
#  ('2021', 'Chris Godwin', 14, 10.0, 0.82, 'Top half scorer', 'Bottom half availability'),
#  ('2021', 'Adam Thielen', 13, 10.0, 0.76, 'Top half scorer', 'Bottom half availability'),
#  ('2021', 'Robert Woods', 9, 10.0, 0.53, 'Top half scorer', 'Bottom half availability'),
#  ('2022', 'Keenan Allen', 10, 10.0, 0.59, 'Top half scorer', 'Bottom half availability'),
#  ('2022', 'DeAndre Hopkins', 9, 10.0, 0.53, 'Top half scorer', 'Bottom half availability'),
#  ('2023', 'Mike Williams', 3, 10.0, 0.18, 'Top half scorer', 'Bottom half availability'),
#  ('2017', 'Robert Woods', 12, 9.0, 0.75, 'Top half scorer', 'Bottom half availability'),
#  ('2017', 'Will Fuller', 10, 9.0, 0.63, 'Top half scorer', 'Bottom half availability'),
#  ('2018', 'Alshon Jeffery', 13, 9.0, 0.81, 'Top half scorer', 'Bottom half availability'),
#  ('2018', 'DeSean Jackson', 12, 9.0, 0.75, 'Top half scorer', 'Bottom half availability'),
#  ('2018', 'Marvin Jones', 9, 9.0, 0.56, 'Top half scorer', 'Bottom half availability'),
#  ('2019', 'Golden Tate', 11, 9.0, 0.69, 'Top half scorer', 'Bottom half availability'),
#  ('2019', 'Sterling Shepard', 10, 9.0, 0.63, 'Top half scorer', 'Bottom half availability'),
#  ('2019', 'DeSean Jackson', 3, 9.0, 0.19, 'Top half scorer', 'Bottom half availability'),
#  ('2020', 'Jamison Crowder', 12, 9.0, 0.75, 'Top half scorer', 'Bottom half availability'),
#  ('2020', 'Antonio Brown', 8, 9.0, 0.5, 'Top half scorer', 'Bottom half availability'),
#  ('2020', 'Odell Beckham Jr.', 7, 9.0, 0.44, 'Top half scorer', 'Bottom half availability'),
#  ('2020', 'Kenny Golladay', 5, 9.0, 0.31, 'Top half scorer', 'Bottom half availability'),
#  ('2021', 'A.J. Brown', 13, 9.0, 0.76, 'Top half scorer', 'Bottom half availability'),
#  ('2021', 'Elijah Moore', 11, 9.0, 0.65, 'Top half scorer', 'Bottom half availability'),
#  ('2021', 'Henry Ruggs III', 7, 9.0, 0.41, 'Top half scorer', 'Bottom half availability'),
#  ('2022', 'Christian Watson', 14, 9.0, 0.82, 'Top half scorer', 'Bottom half availability'),
#  ('2022', 'Mike Williams', 13, 9.0, 0.76, 'Top half scorer', 'Bottom half availability'),
#  ('2022', 'Deebo Samuel', 13, 9.0, 0.76, 'Top half scorer', 'Bottom half availability'),
#  ('2022', 'Mecole Hardman', 8, 9.0, 0.47, 'Top half scorer', 'Bottom half availability'),
#  ('2023', 'Jaylen Waddle', 14, 9.0, 0.82, 'Top half scorer', 'Bottom half availability'),
#  ('2023', 'Cooper Kupp', 12, 9.0, 0.71, 'Top half scorer', 'Bottom half availability')]

# %% [markdown]
# ### which qbs busted?

# %%
# %%sql
# SELECT
#     year,
#     player,
#     g,
#     fppg,
#     pgp,
#     score_flag,
#     availability_flag
# FROM pgp_tag
# WHERE 1=1
#     AND fantasy_pos = 'QB'
#     AND score_flag LIKE 'Top%'
#     AND availability_flag NOT LIKE 'Top%'
# ORDER BY fppg DESC
# ;
# Out:
#  * sqlite:////Users/beoconno/Documents/ff/ff_data/raw_data/nfl/src_code/nfl.db
# Done.
# [('2020', 'Dak Prescott', 5, 27.0, 0.31, 'Top half scorer', 'Bottom half availability'),
#  ('2017', 'Deshaun Watson', 7, 24.0, 0.44, 'Top half scorer', 'Bottom half availability'),
#  ('2018', 'Ryan Fitzpatrick', 8, 21.0, 0.5, 'Top half scorer', 'Bottom half availability'),
#  ('2019', 'Matthew Stafford', 8, 21.0, 0.5, 'Top half scorer', 'Bottom half availability'),
#  ('2019', 'Drew Brees*', 11, 20.0, 0.69, 'Top half scorer', 'Bottom half availability'),
#  ('2023', 'Joe Flacco', 5, 20.0, 0.29, 'Top half scorer', 'Bottom half availability'),
#  ('2017', 'Aaron Rodgers', 7, 19.0, 0.44, 'Top half scorer', 'Bottom half availability'),
#  ('2019', 'Jeff Driskel', 3, 19.0, 0.19, 'Top half scorer', 'Bottom half availability'),
#  ('2023', 'Kirk Cousins', 8, 19.0, 0.47, 'Top half scorer', 'Bottom half availability'),
#  ('2018', 'Jameis Winston', 11, 18.0, 0.69, 'Top half scorer', 'Bottom half availability'),
#  ('2018', 'Carson Wentz', 11, 18.0, 0.69, 'Top half scorer', 'Bottom half availability'),
#  ('2020', 'Gardner Minshew II', 9, 18.0, 0.56, 'Top half scorer', 'Bottom half availability'),
#  ('2022', 'Kyler Murray', 11, 18.0, 0.65, 'Top half scorer', 'Bottom half availability'),
#  ('2023', 'Kyler Murray', 8, 18.0, 0.47, 'Top half scorer', 'Bottom half availability'),
#  ('2023', 'Anthony Richardson', 4, 18.0, 0.24, 'Top half scorer', 'Bottom half availability'),
#  ('2020', 'Joe Burrow', 10, 17.0, 0.63, 'Top half scorer', 'Bottom half availability'),
#  ('2020', 'Ryan Fitzpatrick', 9, 17.0, 0.56, 'Top half scorer', 'Bottom half availability'),
#  ('2021', 'Jameis Winston', 7, 17.0, 0.41, 'Top half scorer', 'Bottom half availability'),
#  ('2018', 'Andy Dalton', 11, 16.0, 0.69, 'Top half scorer', 'Bottom half availability'),
#  ('2018', 'Jimmy Garoppolo', 3, 16.0, 0.19, 'Top half scorer', 'Bottom half availability'),
#  ('2023', 'Jake Browning', 9, 16.0, 0.53, 'Top half scorer', 'Bottom half availability'),
#  ('2017', 'Carson Palmer', 7, 15.0, 0.44, 'Top half scorer', 'Bottom half availability'),
#  ('2017', 'Jimmy Garoppolo', 6, 15.0, 0.38, 'Top half scorer', 'Bottom half availability'),
#  ('2018', 'Joe Flacco', 9, 15.0, 0.56, 'Top half scorer', 'Bottom half availability'),
#  ('2018', 'Nick Mullens', 8, 15.0, 0.5, 'Top half scorer', 'Bottom half availability'),
#  ('2018', 'Nick Foles', 5, 15.0, 0.31, 'Top half scorer', 'Bottom half availability'),
#  ('2020', 'Mitchell Trubisky', 10, 15.0, 0.63, 'Top half scorer', 'Bottom half availability'),
#  ('2021', 'Daniel Jones', 11, 15.0, 0.65, 'Top half scorer', 'Bottom half availability'),
#  ('2021', 'Trevor Siemian', 6, 15.0, 0.35, 'Top half scorer', 'Bottom half availability'),
#  ('2022', 'Jimmy Garoppolo', 11, 15.0, 0.65, 'Top half scorer', 'Bottom half availability'),
#  ('2022', 'Jameis Winston', 3, 15.0, 0.18, 'Top half scorer', 'Bottom half availability'),
#  ('2023', 'Joe Burrow', 10, 15.0, 0.59, 'Top half scorer', 'Bottom half availability'),
#  ('2023', 'Deshaun Watson', 6, 15.0, 0.35, 'Top half scorer', 'Bottom half availability')]

# %% [markdown]
# ### how long are they out?

# %%
# %%sql
# SELECT
#     fantasy_pos,
#     score_flag,
#     availability_flag,
#     ROUND(AVG(g)) AS avg_games_played,
#     ROUND(AVG(fppg)) AS avg_fppg,
#     ROUND(AVG(pgp),3) AS avg_percent_of_season,
#     AVG(fppg) * AVG(pgp) AS fppg_x_pgp_ev
# FROM pgp_tag
# GROUP BY 1, 2, 3
# ORDER BY AVG(fppg) * AVG(pgp) DESC
# ;
# Out:
#  * sqlite:////Users/beoconno/Documents/ff/ff_data/raw_data/nfl/src_code/nfl.db
# Done.
# [('QB', 'Top half scorer', 'Top half availability', 15.0, 18.0, 0.94, 17.341018155927358),
#  ('RB', 'Top half scorer', 'Top half availability', 16.0, 14.0, 0.952, 13.234806533321679),
#  ('QB', 'Bottom half scorer', 'Top half availability', 15.0, 12.0, 0.885, 10.94469381688466),
#  ('WR', 'Top half scorer', 'Top half availability', 16.0, 11.0, 0.967, 10.422748788927327),
#  ('RB', 'Top half scorer', 'Bottom half availability', 11.0, 13.0, 0.657, 8.821222222222222),
#  ('TE', 'Top half scorer', 'Top half availability', 16.0, 9.0, 0.952, 8.806000000000001),
#  ('QB', 'Top half scorer', 'Bottom half availability', 8.0, 17.0, 0.477, 8.334444444444445),
#  ('RB', 'Bottom half scorer', 'Top half availability', 16.0, 8.0, 0.962, 7.65256395002974),
#  ('WR', 'Bottom half scorer', 'Top half availability', 16.0, 7.0, 0.963, 6.727044745057225),
#  ('WR', 'Top half scorer', 'Bottom half availability', 10.0, 10.0, 0.617, 6.3826626275510225),
#  ('TE', 'Bottom half scorer', 'Top half availability', 16.0, 6.0, 0.957, 6.00416478044364),
#  ('TE', 'Top half scorer', 'Bottom half availability', 10.0, 9.0, 0.591, 5.322857142857143),
#  ('RB', 'Bottom half scorer', 'Bottom half availability', 10.0, 8.0, 0.601, 4.864158862296219),
#  ('WR', 'Bottom half scorer', 'Bottom half availability', 10.0, 7.0, 0.625, 4.261818),
#  ('QB', 'Bottom half scorer', 'Bottom half availability', 6.0, 10.0, 0.376, 3.8435251747757926),
#  ('TE', 'Bottom half scorer', 'Bottom half availability', 10.0, 6.0, 0.59, 3.736666666666667)]

# %% [markdown]
# - bottom half RBs play 11 games but are MORE valuable than any other position
# - does this change under ppr or half ppr?

# %% [markdown]
# ###

# %% [markdown]
# ### what's the replacement value?
