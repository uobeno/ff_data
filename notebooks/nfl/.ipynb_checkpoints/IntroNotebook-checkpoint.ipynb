# %% [markdown]
# # Intro notebook
# The purpose of this notebook is to connect to a local database that we created by loading CSV files into that database.
# Copy / paste this notebook into other places to add / delete cells and add new analysis.

# %%
import os
print(os.getcwd())
# Out:
# /Users/beoconno/Documents/ff/ff_data/notebooks/nfl

# %%
from pathlib import Path

# %%
# Define your database file path (SQLite example)
rel_db_path = Path.cwd().parent.parent / 'raw_data' / 'nfl' / 'src_code' / 'nfl.db'
db_file_path = rel_db_path.resolve()

# %%
print(db_file_path)
# Out:
# /Users/beoconno/Documents/ff/ff_data/raw_data/nfl/src_code/nfl.db

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine(f'sqlite:///{db_file_path}')
print(engine)
# Out:
# Engine(sqlite:////Users/beoconno/Documents/ff/ff_data/raw_data/nfl/src_code/nfl.db)

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql sqlite:///{db_file_path}

# %%
# %%sql
# SELECT *
# FROM nfl_adp_names
# LIMIT 10
# Out:
#  * sqlite:////Users/beoconno/Documents/ff/ff_data/raw_data/nfl/src_code/nfl.db
# Done.
# [('Antonio Brown', 1.0, None, 'WR1', 'WR', '2016', 1.0, 'antonio brown', 12, 'Antonio Brown*+', 'PIT', 'WR', 28, 15, 15, 0, 0, 0, 0, 0, 3, 9, 3.0, 0, 154, 106, 1284, 12.11, 12, 0.0, 0, 12, None, None, 201.0, 307.3, 310.3, 254.3, 75.0, 3, 12.0, 'BrowAn04', '2016', 'Antonio Brown', 'true', 'true', 13.4, 13.4, 20.49, 254.0, 0.94, 0.0, 0.2, 10.27, 0.0, 0.0, 0.0, None, None, 0.0, 0.6, None, None, 7.067, 0.688, 0.8, 85.6, 12.83, 8.83, 107.0, 'antonio brown', 'antonio brown', 'Antonio Brown', '2016', 'WR'),
#  ('Julio Jones', 2.0, None, 'WR2', 'WR', '2016', 2.3, 'julio jones', 20, 'Julio Jones*+', 'ATL', 'WR', 27, 14, 14, 0, 0, 0, 0, 0, 0, 0, None, 0, 129, 83, 1409, 16.98, 6, 0.0, 0, 6, None, None, 177.0, 259.9, 262.9, 218.4, 51.0, 6, 20.0, 'JoneJu02', '2016', 'Julio Jones', 'true', 'true', 12.64, 12.64, 18.56, 218.5, 0.88, 0.0, 0.0, 9.21, 0.0, 0.0, 0.0, None, None, 0.0, 0.0, None, None, 5.929, 0.643, 0.4286, 100.64, 21.5, 13.83, 234.83, 'julio jones', 'julio jones', 'Julio Jones', '2016', 'WR'),
#  ('Odell Beckham Jr.', 3.0, 'MIA', 'WR3', 'WR', '2016', 2.8, 'odell beckham', 15, 'Odell Beckham Jr.*', 'NYG', 'WR', 24, 16, 16, 0, 0, 0, 0, 0, 1, 9, 9.0, 0, 169, 101, 1367, 13.53, 10, 3.0, 1, 10, None, None, 196.0, 296.6, 300.6, 246.1, 69.0, 4, 15.0, 'BeckOd00', '2016', 'Odell Beckham Jr.', 'true', 'false', 12.25, 12.25, 18.54, 246.5, 1.0, 0.0, 0.06, 10.56, 0.0, 0.0, 0.0, None, None, 0.0, 0.56, None, None, 6.313, 0.598, 0.625, 85.44, 16.9, 10.1, 136.7, 'odell beckham', 'odell beckham', 'Odell Beckham Jr.', '2016', 'WR'),
#  ('Todd Gurley', 4.0, 'II', 'RB1', 'RB', '2016', 4.8, 'todd gurley', 48, 'Todd Gurley', 'LAR', 'RB', 22, 16, 16, 0, 0, 0, 0, 0, 278, 885, 3.18, 6, 58, 43, 327, 7.6, 0, 2.0, 1, 6, None, None, 155.0, 198.2, 205.2, 176.7, 18.0, 20, 48.0, 'GurlTo01', '2016', 'Todd Gurley', 'false', 'false', 9.69, 9.69, 12.39, 176.5, 1.0, 0.0, 17.38, 3.63, 0.0, 0.0, 0.0, None, None, 0.375, 55.31, 147.5, 46.33, 2.688, 0.741, 0.0, 20.44, None, None, None, 'todd gurley', 'todd gurley', 'Todd Gurley', '2016', 'RB'),
#  ('DeAndre Hopkins', 5.0, 'TEN', 'WR4', 'WR', '2016', 5.8, 'deandre hopkins', 102, 'DeAndre Hopkins', 'HOU', 'WR', 24, 16, 16, 0, 0, 0, 0, 0, 0, 0, None, 0, 151, 78, 954, 12.23, 4, 0.0, 0, 4, None, None, 119.0, 197.4, 200.4, 158.4, None, 36, None, 'HopkDe00', '2016', 'DeAndre Hopkins', 'false', 'false', 7.44, 7.44, 12.34, 158.0, 1.0, 0.0, 0.0, 9.44, 0.0, 0.0, 0.0, None, None, 0.0, 0.0, None, None, 4.875, 0.517, 0.25, 59.63, 37.75, 19.5, 238.5, 'deandre hopkins', 'deandre hopkins', 'DeAndre Hopkins', '2016', 'WR'),
#  ('A.J. Green', 6.0, None, 'WR5', 'WR', '2016', 6.0, 'aj green', 100, 'A.J. Green*', 'CIN', 'WR', 28, 10, 10, 0, 0, 0, 0, 0, 0, 0, None, 0, 100, 66, 964, 14.61, 4, 0.0, 0, 4, None, None, 120.0, 186.4, 189.4, 153.4, None, 34, None, 'GreeA.00', '2016', 'A.J. Green', 'true', 'false', 12.0, 12.0, 18.64, 153.0, 0.63, 0.0, 0.0, 10.0, 0.0, 0.0, 0.0, None, None, 0.0, 0.0, None, None, 6.6, 0.66, 0.4, 96.4, 25.0, 16.5, 241.0, 'aj green', 'aj green', 'A.J. Green', '2016', 'WR'),
#  ('David Johnson', 7.0, None, 'RB2', 'RB', '2016', 6.0, 'david johnson', 1, 'David Johnson*+', 'ARI', 'RB', 25, 16, 16, 0, 0, 0, 0, 0, 293, 1239, 4.23, 16, 120, 80, 879, 10.99, 4, 5.0, 3, 20, 1.0, None, 328.0, 407.8, 416.8, 367.8, 191.0, 1, 1.0, 'JohnDa08', '2016', 'David Johnson', 'true', 'true', 20.5, 20.5, 25.49, 368.0, 1.0, 0.0, 18.31, 7.5, 0.0, 0.0, 0.0, None, None, 1.0, 77.44, 77.44, 18.31, 5.0, 0.667, 0.25, 54.94, 30.0, 20.0, 219.75, 'david johnson', 'david johnson', 'David Johnson', '2016', 'RB'),
#  ('David Johnson', 7.0, None, 'RB2', 'RB', '2016', 6.0, 'david johnson', 388, 'David Johnson', 'PIT', 'TE', 29, 16, 5, 0, 0, 0, 0, 0, 0, 0, None, 0, 11, 7, 80, 11.43, 0, 0.0, 0, 0, 1.0, None, 10.0, 17.0, 17.0, 13.5, None, 71, None, 'JohnDa05', '2016', 'David Johnson', 'false', 'false', 0.63, 2.0, 1.06, 13.5, 1.0, 0.0, 0.0, 0.69, 0.0, 0.0, 0.0, None, None, 0.0, 0.0, None, None, 0.438, 0.636, 0.0, 5.0, None, None, None, 'david johnson', 'david johnson', 'David Johnson', '2016', 'TE'),
#  ('Ezekiel Elliott', 8.0, 'DAL', 'RB3', 'RB', '2016', 9.8, 'ezekiel elliott', 2, 'Ezekiel Elliott*+', 'DAL', 'RB', 21, 15, 15, 0, 0, 0, 0, 0, 322, 1631, 5.07, 15, 39, 32, 363, 11.34, 1, 5.0, 1, 16, None, None, 293.0, 325.4, 332.4, 309.4, 156.0, 2, 2.0, 'ElliEz00', '2016', 'Ezekiel Elliott', 'true', 'true', 19.53, 19.53, 21.69, 309.0, 0.94, 0.0, 21.47, 2.6, 0.0, 0.0, 0.0, None, None, 1.0, 108.73, 108.73, 21.47, 2.133, 0.821, 0.0667, 24.2, 39.0, 32.0, 363.0, 'ezekiel elliott', 'ezekiel elliott', 'Ezekiel Elliott', '2016', 'RB'),
#  ('Allen Robinson II', 9.0, 'NYG', 'WR6', 'WR', '2016', 9.8, 'allen robinson', 94, 'Allen Robinson', 'JAX', 'WR', 23, 16, 16, 0, 0, 0, 0, 0, 0, 0, None, 0, 151, 73, 883, 12.1, 6, 1.0, 0, 6, 1.0, None, 126.0, 199.3, 202.3, 162.8, None, 29, None, 'RobiAl02', '2016', 'Allen Robinson', 'false', 'false', 7.88, 7.88, 12.46, 162.5, 1.0, 0.0, 0.0, 9.44, 0.0, 0.0, 0.0, None, None, 0.0, 0.0, None, None, 4.563, 0.483, 0.375, 55.19, 25.17, 12.17, 147.17, 'allen robinson', 'allen robinson', 'Allen Robinson', '2016', 'WR')]

# %%
# %%sql
# SELECT
#     adp_team,
#     c_team,
#     CASE
#         WHEN team != team_year_prior AND team LIKE '%TM' THEN 'In season trade'
#         WHEN team != team_year_prior THEN 'New team - ffy'
#         ELSE ''
#         END AS team_change,
#     team_year_prior,
#     team_next_year,
#     name,
#     c_year,
#     yid
# FROM nfl_window_stats
# WHERE NAME LIKE '%antonio brown%'
#     OR NAME LIKE '%zack moss%'
#     OR NAME LIKE '%ian mccaffrey%'
# ORDER BY name, c_year ASC
# Out:
#  * sqlite:////Users/beoconno/Documents/ff/ff_data/raw_data/nfl/src_code/nfl.db
# Done.
# [(None, 'PIT', '', None, 'PIT', 'antonio brown', '2016', 1),
#  (None, 'PIT', '', 'PIT', 'PIT', 'antonio brown', '2017', 2),
#  (None, 'PIT', '', 'PIT', 'NWE', 'antonio brown', '2018', 3),
#  (None, 'NWE', 'New team', 'PIT', 'TAM', 'antonio brown', '2019', 4),
#  (None, 'TAM', 'New team', 'NWE', 'TAM', 'antonio brown', '2020', 5),
#  ('TB', 'TAM', '', 'TAM', None, 'antonio brown', '2021', 6),
#  ('SF', 'CAR', '', None, 'CAR', 'christian mccaffrey', '2017', 1),
#  ('SF', 'CAR', '', 'CAR', 'CAR', 'christian mccaffrey', '2018', 2),
#  ('SF', 'CAR', '', 'CAR', 'CAR', 'christian mccaffrey', '2019', 3),
#  ('SF', 'CAR', '', 'CAR', 'CAR', 'christian mccaffrey', '2020', 4),
#  ('CAR', 'CAR', '', 'CAR', '2TM', 'christian mccaffrey', '2021', 5),
#  ('SF', '2TM', 'Trade', 'CAR', 'SFO', 'christian mccaffrey', '2022', 6),
#  ('SF', 'SFO', 'New team', '2TM', 'SF', 'christian mccaffrey', '2023', 7),
#  ('SF', 'SF', '', 'SFO', None, 'christian mccaffrey', '2024', 8),
#  ('WAS', 'WAS', '', None, None, 'luke mccaffrey', '2024', 1),
#  (None, 'JAX', '', None, 'SFO', 'max mccaffrey', '2017', 1),
#  (None, 'SFO', 'New team', 'JAX', None, 'max mccaffrey', '2018', 2),
#  ('CIN', 'BUF', '', None, 'BUF', 'zack moss', '2020', 1),
#  ('BUF', 'BUF', '', 'BUF', '2TM', 'zack moss', '2021', 2),
#  (None, '2TM', 'Trade', 'BUF', 'IND', 'zack moss', '2022', 3),
#  ('CIN', 'IND', 'New team', '2TM', 'CIN', 'zack moss', '2023', 4),
#  ('CIN', 'CIN', '', 'IND', None, 'zack moss', '2024', 5)]

# %%
# %%sql
# SELECT
#     *
# FROM hist_adp_perf
# LIMIT 10
# Out:
#  * sqlite:////Users/beoconno/Documents/ff/ff_data/raw_data/nfl/src_code/nfl.db
# Done.
# [(1, 'QB', 'QB1', 25.09, 8),
#  (1, 'RB', 'RB1', 26.09, 8),
#  (1, 'TE', 'TE1', 17.05, 8),
#  (1, 'WR', 'WR1', 23.2, 8),
#  (2, 'QB', 'QB2', 22.62, 8),
#  (2, 'RB', 'RB2', 22.83, 8),
#  (2, 'TE', 'TE2', 15.59, 8),
#  (2, 'WR', 'WR2', 21.21, 8),
#  (3, 'QB', 'QB3', 22.24, 8),
#  (3, 'RB', 'RB3', 21.08, 8)]

# %%
# %%sql
# SELECT
#     name,
#     c_year,
#     adp_pos,
#     exp_fppg_ppr,
#     prior_fppg_ppr,
#     pick_hype,
#     fppg_ppr,
#     pick_accuracy
# FROM nfl_adp_hype
# WHERE 1=1
#     AND name LIKE '%mahomes%'
# ORDER BY c_year ASC
# LIMIT 10
# Out:
#  * sqlite:////Users/beoconno/Documents/ff/ff_data/raw_data/nfl/src_code/nfl.db
# Done.
# [('patrick mahomes', '2017', 'QB34', 11.77, 0, 11.77, 10.4, -1.37),
#  ('patrick mahomes', '2018', 'QB15', 17.03, 10.4, 6.63, 26.07, 9.04),
#  ('patrick mahomes', '2019', 'QB1', 25.09, 26.07, -0.98, 20.5, -4.59),
#  ('patrick mahomes', '2020', 'QB1', 25.09, 20.5, 4.59, 24.96, -0.13),
#  ('patrick mahomes', '2021', 'QB1', 25.09, 24.96, 0.13, 21.28, -3.81),
#  ('patrick mahomes', '2022', 'QB2', 22.62, 21.28, 1.34, 24.55, 1.93),
#  ('patrick mahomes', '2023', 'QB1', 25.09, 24.55, 0.54, 17.51, -7.58),
#  ('patrick mahomes', '2024', 'QB3', 22.24, 17.51, 4.73, None, 0)]
